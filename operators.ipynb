# %%
a = 17
b = 5

print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Quotient:", a / b)
print("Floor Division:", a // b)
print("Remainder:", a % b)
# Out:
# Sum: 22
# Difference: 12
# Product: 85
# Quotient: 3.4
# Floor Division: 3
# Remainder: 2

# %%
r = 7
pi = 3.14
a = (pi*r**2)
print("Area of the circle:",a)
# Out:
# Area of the circle: 153.86

# %%
p = 1000
rate = 5
time = 3
i = (p*rate*time)/100
print("The rate is:",i)
# Out:
# The rate is: 150.0

# %%
c = 36
F = (c*9/5)+32
print("Temperature is:",F)
# Out:
# Temperature is: 96.8

# %%
num = 29
print("Even:",num % 2==0)
print("Odd:",num % 2!=0)
# Out:
# Even: False
# Odd: True

# %%
x = 45
y = 60
print("x and y are same:",x==y)
print("x and y are not same:",x!=y)
print("x is greater than y:",x > y)
print("x is less than y:",x < y)
print("x is greaterthan or equal to y:",x >= y)
print("x is lessthan or equal to y:",x <= y)
# Out:
# x and y are same: False
# x and y are not same: True
# x is greater than y: False
# x is less than y: True
# x is greaterthan or equal to y: False
# x is lessthan or equal to y: True

# %%
a = 12
b = 45
c = 9

print(a > b)
print(a > c)

print(b > a)
print(b > c)

print(c > a)
print(c > b)
# Out:
# False
# True
# True
# True
# False
# False

# %%
price1 = 250
price2 = 180

print(price1 > price2)
# Out:
# True

# %%
s1 = "apple"
s2 = "banana"

print(s1 < s2)
# Out:
# True

# %%
score = 82

print(score >= 90)
# Out:
# False

# %%
age = 25
has_id = True

print(age >= 18 and has_id)
# Out:
# True

# %%
is_raining = False
is_sunny = True

print(is_raining == False or is_sunny == True)
# Out:
# True

# %%
is_logged_in = True

print(not is_logged_in)
# Out:
# False

# %%
marks = 78

print(marks >= 70 and marks < 85)
# Out:
# True

# %%
has_ticket = True
is_vip = False

print(has_ticket or is_vip)
# Out:
# True

# %%
total = 100

total += 10
print(total)

total -= 10
print(total)

total *= 10
print(total)

total /= 10
print(total)
# Out:
# 110
# 100
# 1000
# 100.0

# %%
count = 5

count **= 3

print(count)
# Out:
# 125

# %%
num = 50

num //= 7

print(num)
# Out:
# 7

# %%
value = 20

value %= 6

print(value)
# Out:
# 2

# %%
flags = 12

flags &= 10

print(flags)
# Out:
# 8

# %%
a = 12
b = 10

print(a & b)
print(a | b)
print(a ^ b)
print(~a)
print(a << 2)
print(a >> 2)
# Out:
# 8
# 14
# 6
# -13
# 48
# 3

# %%
n = 34

print(n & 1 == 0)
# Out:
# True

# %%
x = 5

result = x << 2

print(result)
# Out:
# 20

# %%
list1 = [1, 2, 3]
list2 = [1, 2, 3]

print(list1 == list2)
print(list1 is list2)
# Out:
# True
# False

# %%
fruits = ["apple", "mango", "grape"]

print("banana" in fruits)
print("mango" in fruits)

print("banana" not in fruits)
print("mango" not in fruits)
# Out:
# False
# True
# True
# False
