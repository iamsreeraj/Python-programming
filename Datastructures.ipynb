# %% [markdown]
# # LIST

# %%
fruits = ["Apple","Banana","Cherry"]
print(fruits[1:])
# Out:
# ['Banana', 'Cherry']

# %%
fruits.append("Orange")
fruits.remove("Banana")
print(fruits)
# Out:
# ['Apple', 'Cherry', 'Orange']

# %%
a = ["Pen","Pencil","Eraser"]
a[1] = "Marker"
print(a)
# Out:
# ['Pen', 'Marker', 'Eraser']

# %%
n1 = [1,2,3]
n2 = [4,5,6]
n3 = n1+n2
print(n3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
n4 = [10,20,30,40]
print(len(n4))
# Out:
# 4

# %%
lang = ["C","C++","Python","Java"]
print(lang.index("Python"))
# Out:
# 2

# %%
n5 = [5,2,8,1]
n5.sort()
print(n5)
# Out:
# [1, 2, 5, 8]

# %%
n6 =n5.copy()
print(n6)
# Out:
# [1, 2, 5, 8]

# %%
n7 = [1,3,3,5,3,7]
print(n7.count(3))
# Out:
# 3

# %% [markdown]
# # TUPLE

# %%
colors = ("Red","Black","Blue","Orange","White")
print(type(colors))
# Out:
# <class 'tuple'>

# %%
t1 = (10,20,30,40,50)
print(t1[2])
# Out:
# 30

# %%
t1[2]= 70
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 t1[2]= 70
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = list(t1)
print(type(t1))
# Out:
# <class 'list'>

# %%
d = ('a', 'b', 'c', 'd')
print(len(d))
# Out:
# 4

# %%
print(colors)
print("Blue" in colors)
# Out:
# ('Red', 'Black', 'Blue', 'Orange', 'White')
# True

# %%
t3 = (1,2,3)
t4 = (4,5,6)
t5 = t3 + t4
print(t5)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t6 = ("Hi ")
print(t6*3)
# Out:
# Hi Hi Hi

# %%
t7 = (2,4,5,7,5,9)
print(t7.index(5))
# Out:
# 2

# %%
t8 = ('x','y','x','z')
print(t8.count("x"))
# Out:
# 2

# %% [markdown]
# # SET

# %%
numbers = {1,2,3,4,5,6}
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
numbers.add(7)
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
numbers.remove(5)
print(numbers)
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
num = {1,2,3}
num1 = {2,3,4}
print(num.union(num1))
# Out:
# {1, 2, 3, 4}

# %%
print(num.intersection(num1))
# Out:
# {2, 3}

# %%
num2 = {1,2,3}
num3 = {3,4,5}
print(num2.difference(num3))
# Out:
# {1, 2}

# %%
print(4 in num2)
# Out:
# False

# %%
liss = [1,2,2,3,3,4]
print(set(liss))
# Out:
# {1, 2, 3, 4}

# %%
num5 = {10,20,30}
print(num5.clear())
# Out:
# None

# %%
num6 =num2.copy()
print(num6)
# Out:
# {1, 2, 3}

# %% [markdown]
# # DICTIONARY

# %%
d1 = {"Name":"John","Age":"22","City":"Xlantis"}
print(d1)
# Out:
# {'Name': 'John', 'Age': '22', 'City': 'Xlantis'}
# <class 'dict'>

# %%
m = {"name":"John", "age":25, "city":"Delhi"}
print(m["age"])
# Out:
# 25

# %%
m["country"] = "India"
print(m)
# Out:
# {'name': 'John', 'age': 25, 'city': 'Delhi', 'country': 'India'}

# %%
m["age"] = 30
print(m)
# Out:
# {'name': 'John', 'age': 30, 'city': 'Delhi', 'country': 'India'}

# %%
m.pop("city")
print(m)
# Out:
# {'name': 'John', 'age': 30, 'country': 'India'}

# %%
print(m.keys())
print(m.values())
print(m.items())
# Out:
# dict_keys(['name', 'age', 'country'])
# dict_values(['John', 30, 'India'])
# dict_items([('name', 'John'), ('age', 30), ('country', 'India')])

# %%
h = m.copy()
print(h)
# Out:
# {'name': 'John', 'age': 30, 'country': 'India'}

# %%
keys = ["a","b","c"]
values = [1,2,3]
dict(zip(keys,values))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
