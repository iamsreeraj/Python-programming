# %% [markdown]
# # *Part A -Understanding Data Types*

# %%
Name = "Sreeraj sp"
Height = 6.1
Weight = 78
is_good = True
Food = None
print("Name = ",Name)
print("Height",Height)
print("is_good =",is_good)
print("Food",Food)
# Out:
# Name =  Sreeraj sp
# Height 6.1
# is_good = True
# Food None

# %%
print(type(Name))
print(type(Height))
print(type(Weight))
print(type(is_good))
print(type(Food))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
age = 25
height = 5.6
is_student = True
name = "Anu"
email = None
print(type(age))
print(type(height))
print(type(is_student))
print(type(name))
print(type(email))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>

# %% [markdown]
# Q.Which built-in function can be used to find the data type of a variable?
# Answer : type()
# Q.Which built-in function can be used to find the number of characters in a string?
# Answer : len()

# %%
a = int("25")
b = float("25.5")
c = str(25)
d = str(True)
print(type(d))
# Out:
# <class 'str'>

# %% [markdown]
# Q.Identify the data type of the result of: type("Python")
# Answer : String
# Q.Identify the data type of the result of: len("Python")
# Answer :6
# Q.Identify the data type of: None
# Answer :None

# %% [markdown]
# # *Part B -String Properties & Basic inspection*

# %%
txt = "Python Programming"
print(len(txt))
print(txt[0])
print(txt[-1])
print(txt[3])
print(txt[7])
print(txt[:5])
print(txt[-5:])
print(txt[::-1])
print(txt[::2])
print(txt[0:6])
print(txt[7:17])
print(txt.find("P"))
print(txt.index("Programming"))
print("Python" in txt)
print("Java" in txt)
# Out:
# 18
# P
# g
# h
# P
# Pytho
# mming
# gnimmargorP nohtyP
# Pto rgamn
# Python
# Programmin
# 0
# 7
# True
# False

# %% [markdown]
# # *Part C -String Case Methhods*

# %%
text = "Python programming language"
print(txt.upper())
print(txt.lower())
print(txt.capitalize())
print(txt.title())
# Out:
# PYTHON PROGRAMMING
# python programming
# Python programming
# Python Programming

# %%
t = "PYTHON PROGRAMMING"
print(t.lower())
# Out:
# python programming

# %%
y = "pYtHoN pRoGrAmMiNg"
print(y.title())
print(y.islower())
print(y.isupper())
print(y.istitle())
# Out:
# Python Programming
# False
# False
# False

# %% [markdown]
# # *Part D - Searching Strings*

# %%
sentence = "Python is easy to learn and Python is powerful"
print("Python" in sentence)
print("Java" in sentence)
print(sentence.find("Python"))
print(sentence.count("is"))
print(sentence.startswith("Python"))
print(sentence.endswith("powerful"))
print(sentence.startswith("Java"))
print(sentence.find("powerful"))
print(sentence.count("o"))
# Out:
# True
# False
# 0
# 2
# True
# True
# False
# 38
# 4

# %% [markdown]
# # *Part E - Cleaning string*

# %%
name = "  shahma cp  "
print(name.strip())
print(name.lstrip())
print(name.rstrip())
clean = name.strip()
print(clean.title())
# Out:
# shahma cp
# shahma cp
#   shahma cp
# Shahma Cp

# %%
text = "Python   is   easy   to   learn"
text = text.replace("   "," ")
print(text)
# Out:
# Python is easy to learn

# %%
email = "  STUDENT@GMAIL.COM  "
email = email.strip()
print(email.lower())
# Out:
# student@gmail.com

# %% [markdown]
# # *Part F -Replace & Modify Strings*

# %%
sentence = "i am learning Java"
print(sentence.replace("Java","Python"))
print(sentence.replace("learning","studying"))
print(sentence.replace(" ","-"))
# Out:
# i am learning Python
# i am studying Java
# i-am-learning-Java

# %%
text = "Python is easy.Python is popular.Python is powerful"
text = text.replace("Python","Data Science")
print(text)
text = text.replace(".",",")
print(text)
# Out:
# Data Science is easy.Data Science is popular.Data Science is powerful
# Data Science is easy,Data Science is popular,Data Science is powerful

# %%
text = "Python,Java,C++,SQL"
print(text.replace(","," "))
# Out:
# Python Java C++ SQL

# %% [markdown]
# # *Part G -  Split & Join*

# %%
sentence = "Python is a programming language"
sentence = sentence.split()
print(sentence)
print(len(sentence))
print(sentence[0])
print("-".join(sentence))
sentence ="|".join(sentence)
print(sentence)
# Out:
# ['Python', 'is', 'a', 'programming', 'language']
# 5
# Python
# Python-is-a-programming-language
# Python|is|a|programming|language

# %%
languages = ["Python", "Java", "SQL", "R"]
languages = ", ".join(languages)
print(languages)
# Out:
# Python, Java, SQL, R

# %%
text = "Python-Java-SQL-R"
text = text.split("-")
print(text)
text = " ".join(text)
print(text)
# Out:
# ['Python', 'Java', 'SQL', 'R']
# Python Java SQL R

# %% [markdown]
# # *Part H - Character Checking Methods*

# %%
a ="Python"
print(a.isalpha())
b = "Python123"
print(b.isalpha())
c = "12345"
print(c.isdigit())
print(a.islower())
d = "PYTHON"
print(d.isupper())
e = " "
print(e.isspace())
print(b.isnumeric())
print(a.isalpha())
# Out:
# True
# False
# True
# False
# True
# True
# False
# True

# %% [markdown]
# # *Part I - String Counting & Finding*

# %%
text = "Data Science with Python"
print(text.count("a"))
print(text.count(" "))
print(text.count("Python"))
print(text.find("Python"))
print("Data" in text)
print("Machine Learning" in text)
# Out:
# 2
# 3
# 1
# 18
# True
# False

# %% [markdown]
# # *Part J -  Real-World String Problems*

# %% [markdown]
# *Email Analyzer*

# %%
email = "student@gmail.com"
username,domain = email.split("@")
print("Usernamae:",username)
print("Domain:",domain)
print("@" in email)
print(email.endswith(".com"))
print(len(email))
# Out:
# Usernamae: student
# Domain: gmail.com
# True
# True
# 17

# %% [markdown]
# *Name formatter*

# %%
name = "   aNIL kUMAR   "
name = name.strip()
name = name.title()
print(name)
# Out:
# Anil Kumar

# %% [markdown]
# *Usernamae Checker*

# %%
username = "student_123"
print(" " in username)
print("123" in username)#can't use isdigit becuase there is "_" so the output will be False
print(username.startswith("s"))
# Out:
# False
# True
# True

# %% [markdown]
# *Password Analyzer*

# %%
password = "Python@123"
print(password.isupper())
print(password.lower())
print(password.isnumeric())
print("@" in password)
print(" " in password)
# Out:
# False
# python@123
# False
# True
# False

# %% [markdown]
# *Sentence Analyzer*

# %%
sentence = "Python is easy to learn"
print(len(sentence))
words = sentence.split()
print(len(words))
print(sentence.count(" "))
print(words[0])
print(words[4])
print("Longest word:", max(words, key=len))#using this key is not covered yet ...
# Out:
# 23
# 5
# 4
# Python
# learn
# Longest word: Python

# %% [markdown]
# *Text Cleaning*

# %%
text = "   PYTHON is   a powerful programming language   "
text = " ".join(text.split())
text= text.lower()
text = text.capitalize()
print(text)
# Out:
# Python is a powerful programming language
